# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !apt-get install protobuf-compiler python-pil python-lxml python-tk
# !pip install Cython
# !pip install jupyter
# !pip install matplotlib

# %%
# !git clone https://github.com/tensorflow/models.git
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 30825, done.
# remote: Total 30825 (delta 0), reused 0 (delta 0), pack-reused 30825
# Receiving objects: 100% (30825/30825), 510.57 MiB | 31.00 MiB/s, done.
# Resolving deltas: 100% (19392/19392), done.
# Checking out files: 100% (3078/3078), done.

# %%
# %cd models
# Out:
# /content/models

# %%
# !git checkout 079d67d9a0b3407e8d074a200780f3835413ef99 .

# %%
# !ls
# Out:
# AUTHORS     CONTRIBUTING.md    LICENSE	 README.md  samples    WORKSPACE
# CODEOWNERS  ISSUE_TEMPLATE.md  official  research   tutorials

# %%
# %cd research
# Out:
# /content/models/research

# %%
# %set_env PYTHONPATH=/content/models/research:/content/models/research/slim
# Out:
# env: PYTHONPATH=/content/models/research:/content/models/research/slim

# %%
# !protoc object_detection/protos/*.proto --python_out=.

# %%
# !ls

# %%
# !python setup.py build

# %%
# !python setup.py install

# %%
# !python object_detection/builders/model_builder_test.py

# %%
# %cd object_detection
# Out:
# /content/models/research/object_detection

# %%
# !python train.py --logtostderr --train_dir='/content/drive/My Drive/Tensorflow_train/Models/' --pipeline_config_path='/content/drive/My Drive/Tensorflow_train/faster_rcnn_inception_v2_pets.config'
# Out:
# INFO:tensorflow:global step 6871: loss = 0.0266 (0.349 sec/step)
# I0922 15:30:32.534032 139808843995008 learning.py:507] global step 6871: loss = 0.0266 (0.349 sec/step)
# INFO:tensorflow:global step 6872: loss = 0.0327 (0.373 sec/step)
# I0922 15:30:32.909302 139808843995008 learning.py:507] global step 6872: loss = 0.0327 (0.373 sec/step)
# INFO:tensorflow:global step 6873: loss = 0.0564 (0.364 sec/step)
# I0922 15:30:33.275156 139808843995008 learning.py:507] global step 6873: loss = 0.0564 (0.364 sec/step)
# INFO:tensorflow:global step 6874: loss = 0.0287 (0.352 sec/step)
# I0922 15:30:33.629464 139808843995008 learning.py:507] global step 6874: loss = 0.0287 (0.352 sec/step)
# INFO:tensorflow:global step 6875: loss = 0.1726 (0.307 sec/step)
# I0922 15:30:33.938262 139808843995008 learning.py:507] global step 6875: loss = 0.1726 (0.307 sec/step)
# INFO:tensorflow:global step 6876: loss = 0.0522 (0.348 sec/step)
# ...
